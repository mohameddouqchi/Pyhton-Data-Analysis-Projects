# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
my_data = pd.read_csv('movies.csv')

# %%
my_data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
my_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
my_data.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
my_data.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
my_data.head(3)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
#
#          gross            company  runtime
# 0   46998772.0       Warner Bros.    146.0
# ...

# %%
my_data = my_data.fillna(0)
my_data['budget'] = my_data.budget.astype(int)
my_data['gross'] = my_data.gross.astype(int)

# %%
my_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
my_data['CorrectYear'] = my_data['released'].astype(str).str[7:14]

# %%
my_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
my_data.drop('CorrectYear',  inplace=True, axis=1)

# %%
my_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
my_data['released'][1].split()
# Out:
# ['July', '2,', '1980', '(United', 'States)']

# %%
my_data.drop('released', axis=1)
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
my_data = my_data.sort_values(by='gross', inplace= False, ascending= False)

# %%
plt.scatter(x=my_data['budget'], y=my_data['gross'])
plt.title('Budget vs Gross')
plt.xlabel('Budget')
plt.ylabel('gross')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.regplot(x= 'budget', y='gross', data= my_data, scatter_kws={'color': 'red'}, line_kws={'color': 'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
my_data.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.256331  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.169154  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.573930  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.687124  0.268372
# gross    0.256331  0.169154  0.573930  0.687124  1.000000  0.203616
# runtime  0.116358  0.394564  0.306984  0.268372  0.203616  1.000000

# %%
corr_matrix = my_data.corr(method='pearson')
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation matrix')
plt.xlabel('Movies features')
plt.ylabel('Movies features')
plt.show()

# %%
my_data['company']
# Out:
# 6663                Lucasfilm
# 7244           Marvel Studios
# 7480     Walt Disney Pictures
# 6653       Universal Pictures
# 6043           Marvel Studios
#                 ...
# 5033        Big Easy Pictures
# 7667              PK 65 Films
# 3045    Twentieth Century Fox
# 7445           Marvel Studios
# 5445    Twentieth Century Fox
# Name: company, Length: 7668, dtype: object

# %%
df_num = my_data
for i in df_num:
    if df_num[i].dtype == 'object':
        df_num[i] = my_data[i].astype('category')
        df_num[i] = my_data[i].cat.codes
df_num
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 6663  5144       6      0  2015       699    7.8   876000.0      1125    2551
# 7244   536       6      0  2018       193    8.4   897000.0       162     744
# 7480  6194       5      2  2019      1489    6.9   222000.0      1455    1920
# 6653  2969       6      0  2015      1705    7.0   593000.0       517    3569
# 6043  5502       6      0  2012      2473    8.0  1300000.0      1517    2315
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5033  3372       4      6  2006      2393    6.3    12000.0      1563    2398
# 7667  5394       0     10  2020       392    5.7        7.0      2165    3345
# 3045  6896       6      6  1997       705    7.8  1100000.0      1155    1779
# 7445   535       6      0  2019       184    8.4   903000.0       162     744
# 5445   533       6      0  2009       697    7.8  1100000.0      1155    1779
#
# ...

# %%
df_num.copy()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 6663  5144       6      0  2015       699    7.8   876000.0      1125    2551
# 7244   536       6      0  2018       193    8.4   897000.0       162     744
# 7480  6194       5      2  2019      1489    6.9   222000.0      1455    1920
# 6653  2969       6      0  2015      1705    7.0   593000.0       517    3569
# 6043  5502       6      0  2012      2473    8.0  1300000.0      1517    2315
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5033  3372       4      6  2006      2393    6.3    12000.0      1563    2398
# 7667  5394       0     10  2020       392    5.7        7.0      2165    3345
# 3045  6896       6      6  1997       705    7.8  1100000.0      1155    1779
# 7445   535       6      0  2019       184    8.4   903000.0       162     744
# 5445   533       6      0  2009       697    7.8  1100000.0      1155    1779
#
# ...

# %%
correlation_matrix = my_data.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()
