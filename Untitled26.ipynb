# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
import requests

# %%
from io import StringIO

# %%
url = " http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.csv?"
source = requests.get(url).text
pull_data = StringIO(source)

# %%
df = pd.read_csv(pull_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Pollster                586 non-null    object
#  1   Start Date              586 non-null    object
#  2   End Date                586 non-null    object
#  3   Entry Date/Time (ET)    586 non-null    object
#  4   Number of Observations  564 non-null    float64
#  5   Population              586 non-null    object
#  6   Mode                    586 non-null    object
#  7   Obama                   586 non-null    float64
#  8   Romney                  586 non-null    float64
#  9   Undecided               423 non-null    float64
#  10  Other                   202 non-null    float64
#  11  Pollster URL            586 non-null    object
#  12  Source URL              584 non-null    object
#  13  Partisan                586 non-null    object
# ...

# %%
df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
sns.factorplot('Affiliation',data=df, kind='count')
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Affiliation', data=df,kind='count', hue='Population')
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
avg = pd.DataFrame(df.mean())
avg
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_18156\2557609424.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg = pd.DataFrame(df.mean())
#                                   0
# Number of Observations  1296.679078
# Obama                     46.805461
# Romney                    44.614334
# Undecided                  6.550827
# Other                      3.376238
# Question Text                   NaN
# Question Iteration         1.000000

# %%
avg.drop('Other', axis=0, inplace=True)
avg.drop('Question Text', axis=0, inplace=True)
avg.drop('Question Iteration', axis=0, inplace=True)
avg.drop('Number of Observations',axis=0, inplace=True)

# %%
avg
# Out:
#                    0
# Obama      46.805461
# Romney     44.614334
# Undecided   6.550827

# %%
std = pd.DataFrame(df.std())
std
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_18156\1968708047.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std = pd.DataFrame(df.std())
#                                   0
# Number of Observations  1621.268369
# Obama                      2.422058
# Romney                     2.906180
# Undecided                  3.701754
# Other                      2.692726
# Question Text                   NaN
# Question Iteration         0.000000

# %%
std.drop('Other', axis=0, inplace=True)
std.drop('Question Text', axis=0, inplace=True)
std.drop('Question Iteration', axis=0, inplace=True)
std.drop('Number of Observations',axis=0, inplace=True)

# %%
std
# Out:
#                   0
# Obama      2.422058
# Romney     2.906180
# Undecided  3.701754

# %%
avg.plot(yerr=std,kind='bar',legend=False)
# Out:
# <AxesSubplot:>

# %%
poll_avg = pd.concat([avg,std],axis=1)
poll_avg.columns = ['Average','STD']
poll_avg
# Out:
#              Average       STD
# Obama      46.805461  2.422058
# Romney     44.614334  2.906180
# Undecided   6.550827  3.701754

# %%
df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
df.plot(x='End Date', y=['Obama','Romney','Undecided'], linestyle='', marker='o')
# Out:
# <AxesSubplot:xlabel='End Date'>

# %%
df.drop('Diffrence', axis=1, inplace=True)

# %%
df['Diffrence'] = (df.Obama - df.Romney)/100
df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
from datetime import datetime

# %%
my_df = df.copy()

# %%
my_df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
my_df = my_df.groupby(['Start Date'], as_index=False).mean()
my_df.head()
# Out:
#    Start Date  Number of Observations  Obama  Romney  Undecided  Other  \
# 0  2009-03-13                  1403.0   44.0    44.0       12.0    NaN
# 1  2009-04-17                   686.0   50.0    39.0       11.0    NaN
# 2  2009-05-14                  1000.0   53.0    35.0       12.0    NaN
# 3  2009-06-12                   638.0   48.0    40.0       12.0    NaN
# 4  2009-07-15                   577.0   49.0    40.0       11.0    NaN
#
#    Question Text  Question Iteration  Diffrence
# 0            NaN                 1.0       0.00
# 1            NaN                 1.0       0.11
# 2            NaN                 1.0       0.18
# 3            NaN                 1.0       0.08
# 4            NaN                 1.0       0.09

# %%
my_df.drop('Other', axis=1, inplace=True)
my_df.drop('Question Text', axis=1, inplace=True)
my_df.drop('Question Iteration', axis=1, inplace=True)

# %%
my_df.head()
# Out:
#    Start Date  Number of Observations  Obama  Romney  Undecided  Diffrence
# 0  2009-03-13                  1403.0   44.0    44.0       12.0       0.00
# 1  2009-04-17                   686.0   50.0    39.0       11.0       0.11
# 2  2009-05-14                  1000.0   53.0    35.0       12.0       0.18
# 3  2009-06-12                   638.0   48.0    40.0       12.0       0.08
# 4  2009-07-15                   577.0   49.0    40.0       11.0       0.09

# %%
my_df.plot('Start Date','Diffrence',figsize=(12,4),marker='o',linestyle='-',color='Red')
# Out:
# <AxesSubplot:xlabel='Start Date'>

# %%
row = 0
limit = []

# %%
for i in my_df['Start Date']:
    if i[0:7] == '2012-10':
        limit.append(row)
        row += 1
    else:
        row += 1

# %%
print(min(limit))
print(max(limit))
# Out:
# 325
# 352

# %%
my_df.plot('Start Date','Diffrence',figsize=(12,4),marker='o',linestyle='-',color='Red', xlim=(325,352))
plt.axvline(x=325+2,linewidth=4,color='Black')
plt.axvline(x=325+10,linewidth=4,color='Black')
plt.axvline(x=325+21,linewidth=4,color='Black')
